# %%
import pandas as pd
import numpy as np
import statistics
import matplotlib.pyplot as plt
from sklearn.cluster import AgglomerativeClustering, KMeans, DBSCAN, OPTICS, Birch
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler
from numba import njit, prange
import itertools
import math
import haversine as hs
import requests
import json
import time
from main import *

# %%
df = pd.read_excel('CargoSample.xlsx')
df = df.dropna()
# df lat and long to list
df_lat = df['LatitudePoint'].tolist()
df_long = df['LongitudePoint'].tolist()
df_lat_long = list(zip(df_lat, df_long))
df_lat_long
# Out:
# [(38.475766, 47.063073),
#  (38.475766, 47.063073),
#  (38.475766, 47.063073),
#  (38.061419, 46.322348),
#  (38.061419, 46.322348),
#  (38.061419, 46.322348),
#  (38.075272, 46.287448),
#  (38.075272, 46.287448),
#  (38.075272, 46.287448),
#  (38.075466, 46.343969),
#  (38.075466, 46.343969),
#  (38.075466, 46.343969),
#  (38.102226, 46.285397),
#  (38.100155, 46.296599),
#  (38.100155, 46.296599),
#  (38.066342, 46.323228),
#  (38.073852, 46.288925),
#  (38.073852, 46.288925),
#  (38.073852, 46.288925),
#  (38.073852, 46.288925),
#  (38.079144, 46.287858),
#  (38.079144, 46.287858),
#  (38.079144, 46.287858),
#  (38.072503, 46.301797),
#  (38.072503, 46.301797),
#  (38.078116, 46.325898),
#  (38.078116, 46.325898),
#  (38.078116, 46.325898),
#  (38.054802, 46.273927),
#  (38.054802, 46.273927),
#  (38.106637, 46.285609),
#  (38.106637, 46.285609),
#  (37.782122, 45.904597),
#  (37.782122, 45.904597),
#  (37.3920331, 46.2385937),
#  (37.3920331, 46.2385937),
# ...

# %%
routerOptimizer = RouteOptimizer(df_lat_long, 5, 10)
routerOptimizer.optimize()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[7], line 2
#       1 routerOptimizer = RouteOptimizer(df_lat_long, 5, 10)
# ----> 2 routerOptimizer.optimize()
#
# File c:\Users\alast\MapRecommendationSystemForVisitors\main.py:12, in RouteOptimizer.optimize(self)
#      10 def optimize(self):
#      11     models = self.cluster_data()
# ---> 12     best_model = self.calculate_best_model(models)
#      13     return best_model
#
# File c:\Users\alast\MapRecommendationSystemForVisitors\main.py:66, in RouteOptimizer.calculate_best_model(self, models)
#      64     score = calculate_cluster_score(model, self.coordinates)
#      65     scores.append(score)
# ---> 66 best_model_index = scores.index(max(scores))
#      67 return models[best_model_index]
#
# ValueError: max() arg is an empty sequence
